# %%
import numpy as np
import pandas as pd

# %%
# df2 = pd.read_csv("Vaccinations_us.csv", parse_dates = ['Date'])

# %%
pd.set_option('max_columns', None)

# %%
read_file = pd.read_csv (r'Vaccinations_us.txt')
read_file.to_csv (r'Vaccinations_us.csv', index=None)

# %%
df1 = pd.read_csv("Vaccinations_us.csv")

# %%
df1
# Out:
#              Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 0      12/08/2021         49       KS      4876755               243100
# 1      12/08/2021         49       GU       270490                22500
# 2      12/08/2021         49       MT      1676425                99400
# 3      12/08/2021         49       RP        34190                 3800
# 4      12/08/2021         49      DD2      5904720               208200
# ...           ...        ...      ...          ...                  ...
# 23315  12/13/2020         51       AS         3900                    0
# 23316  12/13/2020         51       US        13650                    0
# 23317  12/13/2020         51       GU         3900                    0
# 23318  12/13/2020         51       MP         4875                    0
# 23319  12/13/2020         51       VI          975                    0
#
#        Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf  \
# ...

# %%
df1.loc[df1['Location'] == 'NY']
# Out:
#              Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 33     12/08/2021         49       NY     36670875              1702000
# 74     12/07/2021         49       NY     36401405              1699100
# 139    12/06/2021         49       NY     36218565              1696300
# 192    12/05/2021         49       NY     36238675              1696300
# 270    12/04/2021         48       NY     36272085              1696300
# ...           ...        ...      ...          ...                  ...
# 23013  12/18/2020         51       NY       151125                    0
# 23097  12/17/2020         51       NY       151125                    0
# 23179  12/16/2020         51       NY        90675                    0
# 23218  12/15/2020         51       NY        87750                    0
# 23292  12/14/2020         51       NY        10725                    0
#
#        Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf  \
# ...

# %%
len(df1.Location.unique())
# Out:
# 65

# %%
df1.Location.unique()
# Out:
# array(['KS', 'GU', 'MT', 'RP', 'DD2', 'UT', 'MN', 'MP', 'MA', 'WA', 'WI',
#        'RI', 'AZ', 'IA', 'MH', 'DC', 'IL', 'TN', 'NC', 'VI', 'VA', 'PR',
#        'CO', 'ID', 'GA', 'US', 'SD', 'VA2', 'IH2', 'NH', 'OH', 'AR', 'IN',
#        'NY', 'VT', 'MS', 'WV', 'FM', 'CA', 'NV', 'ME', 'PA', 'AS', 'KY',
#        'HI', 'ND', 'CT', 'WY', 'MD', 'OK', 'LA', 'NE', 'BP2', 'OR', 'TX',
#        'FL', 'AK', 'NJ', 'SC', 'DE', 'MO', 'MI', 'AL', 'NM', 'LTC'],
#       dtype=object)

# %%
print(sorted(df1.Location.unique()))
# Out:
# ['AK', 'AL', 'AR', 'AS', 'AZ', 'BP2', 'CA', 'CO', 'CT', 'DC', 'DD2', 'DE', 'FL', 'FM', 'GA', 'GU', 'HI', 'IA', 'ID', 'IH2', 'IL', 'IN', 'KS', 'KY', 'LA', 'LTC', 'MA', 'MD', 'ME', 'MH', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'RP', 'SC', 'SD', 'TN', 'TX', 'US', 'UT', 'VA', 'VA2', 'VI', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
# took out 'DC' District of Columbia
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
d1clean = df1[df1['Location'].isin(states)]

# %%
# not taken into account difference dose 1 and 2
df = d1clean[['Date', 'MMWR_week', 'Location', 'Distributed', 'Dist_Per_100K', 'Administered',
             'Admin_Per_100K', 'Admin_Per_100k_12Plus', 'Admin_Per_100k_18Plus', 'Admin_Per_100k_65Plus']]

# %%
df.to_csv(r'vaccination_cleaned_us.csv', index=None)
